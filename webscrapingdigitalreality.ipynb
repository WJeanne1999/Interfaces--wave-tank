# %% [markdown]
# <a href="https://colab.research.google.com/github/WJeanne1999/Interfaces--wave-tank/blob/main/webscrapingdigitalreality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from lxml import html

# URL of the webpage
url = 'https://www.digitalrealty.com/data-centers/emea/london'

# Fetch the webpage
response = requests.get(url)

print(response)

# Check if request was successful
if response.status_code == 200:
    # Parse the HTML content
    tree = html.fromstring(response.text)

    # Use XPath to select elements
    elements = tree.xpath('//*[@id="__NEXT_DATA__"]')

    # Do something with the selected elements
    for element in elements:
        print(html.tostring(element))
else:
    print(f"Failed to fetch webpage. Status code: {response.status_code}")
# Out:
# <Response [200]>
# ...

# %%
import requests
import json
from lxml import html

# URL of the webpage
url = 'https://www.digitalrealty.com/data-centers/emea/london'

# Fetch the webpage
response = requests.get(url)

# Check if request was successful
if response.status_code == 200:
    # Parse the HTML content
    tree = html.fromstring(response.text)

    # Use XPath to select the element with id="__NEXT_DATA__"
    element = tree.xpath('//*[@id="__NEXT_DATA__"]/text()')

    if element:
        # Load the JSON content from the element
        json_data = json.loads(element[0])

        # Define a recursive function to print JSON data hierarchically
        def print_json_hierarchy(data, indent=0):
            indent_str = '  ' * indent
            if isinstance(data, dict):
                for key, value in data.items():
                    print(f"{indent_str}{key}:")
                    print_json_hierarchy(value, indent + 1)
            elif isinstance(data, list):
                for index, item in enumerate(data):
                    print(f"{indent_str}[{index}]:")
                    print_json_hierarchy(item, indent + 1)
            else:
                print(f"{indent_str}{data}")

        # Print the JSON data hierarchically
        print_json_hierarchy(json_data)
    else:
        print("Element with id='__NEXT_DATA__' not found.")
else:
    print(f"Failed to fetch webpage. Status code: {response.status_code}")
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#         field_no_hover:
#           Off
#         field_only_tablet:
#           Off
#         field_go_to_resources:
#           Off
#         field_pull_group_up_in_tablet_mo:
#           Off
#         field_double_pull_group_up_in_ta:
#           Off
#       [4]:
#         name:
#           Digital Transformation
#         id:
#           48
#         parent_id:
#           40
#         description:
#
#         url:
#           /taxonomy/term/48
#         link:
#
#         weight:
#           0
#         field_group_number:
#
#         field_menu_description:
#
#         field_is_email:
#           Off
#         field_is_phone_number:
#           Off
#         field_no_hover:
#           Off
#         field_only_tablet:
#           Off
#         field_go_to_resources:
#           Off
#         field_pull_group_up_in_tablet_mo:
#           Off
#         field_double_pull_group_up_in_ta:
#           Off
# ...

# %%
# !pip install beautifulsoup4

# %%
import requests
from lxml import html
from bs4 import BeautifulSoup

root = 'https://www.digitalrealty.com'
website = f'{root}/data-centers/emea/london'

result = requests.get(website)
content = result.text
soup = BeautifulSoup(content, 'lxml')


box = soup.find(class_='template-metro-map')
# box.find_all('a', href=True)

links = []

for link in box.find_all('a', href=True):
    links += [link['href']]

# %%
links
# Out:
# ['/data-centers/emea/london/lgw10',
#  '/data-centers/emea/london/lgw11',
#  '/data-centers/emea/london/lgw14',
#  '/data-centers/emea/london/lgw15',
#  '/data-centers/emea/london/lgw16',
#  '/data-centers/emea/london/lhr13',
#  '/data-centers/emea/london/lhr17',
#  '/data-centers/emea/london/lhr18',
#  '/data-centers/emea/london/lhr19',
#  '/data-centers/emea/london/lhr20',
#  '/data-centers/emea/london/lon1',
#  '/data-centers/emea/london/lon2',
#  '/data-centers/emea/london/lon3']

# %%
for link in links:
    result = requests.get(f'{root}/{link}')
    content = result.text
    soup = BeautifulSoup(content, 'lxml')

    print(content)
# Out:
# <!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><script src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" data-document-language="true" type="text/javascript" charset="UTF-8" data-domain-script="ec376bc6-9b0b-4f57-a6d8-2d6c73d285c5"></script><script>function OptanonWrapper() { }</script><script>
#                     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#                     })(window,document,'script','dataLayer','GTM-T2MV27');
# ...
